# %% [markdown]
# Created one simple model, to get the understanding of keras

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Activation, Dense

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_testing_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Load the data we make to use to make a prediction
X = pd.read_csv("proposed_new_product.csv").values

# Make a prediction with the neural network
prediction = model.predict(X)

# Grab just the first element of the first prediction (since that's the only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))

model.save('my_trained_model.h5')
print('Model have been saved successfully.')
# Out:
# Using TensorFlow backend.
# Epoch 1/50
#  - 0s - loss: 0.0299
# Epoch 2/50
#  - 0s - loss: 0.0066
# Epoch 3/50
#  - 0s - loss: 0.0026
# Epoch 4/50
#  - 0s - loss: 0.0011
# Epoch 5/50
#  - 0s - loss: 5.9251e-04
# Epoch 6/50
#  - 0s - loss: 3.4820e-04
# Epoch 7/50
#  - 0s - loss: 2.0951e-04
# Epoch 8/50
#  - 0s - loss: 1.5157e-04
# Epoch 9/50
#  - 0s - loss: 1.1911e-04
# Epoch 10/50
#  - 0s - loss: 9.8986e-05
# Epoch 11/50
#  - 0s - loss: 8.4672e-05
# Epoch 12/50
#  - 0s - loss: 7.2611e-05
# Epoch 13/50
#  - 0s - loss: 5.7521e-05
# Epoch 14/50
#  - 0s - loss: 5.5524e-05
# Epoch 15/50
#  - 0s - loss: 5.0463e-05
# Epoch 16/50
#  - 0s - loss: 4.5029e-05
# Epoch 17/50
#  - 0s - loss: 4.3292e-05
# Epoch 18/50
#  - 0s - loss: 3.9073e-05
# Epoch 19/50
#  - 0s - loss: 3.6960e-05
# Epoch 20/50
#  - 0s - loss: 3.0967e-05
# Epoch 21/50
#  - 0s - loss: 3.0129e-05
# Epoch 22/50
#  - 0s - loss: 3.3008e-05
# Epoch 23/50
#  - 0s - loss: 2.9004e-05
# Epoch 24/50
#  - 0s - loss: 2.6244e-05
# Epoch 25/50
#  - 0s - loss: 2.4596e-05
# Epoch 26/50
#  - 0s - loss: 2.3506e-05
# Epoch 27/50
#  - 0s - loss: 2.4458e-05
# Epoch 28/50
#  - 0s - loss: 2.5708e-05
# Epoch 29/50
#  - 0s - loss: 2.3165e-05
# Epoch 30/50
#  - 0s - loss: 2.3454e-05
# Epoch 31/50
#  - 0s - loss: 2.3237e-05
# Epoch 32/50
#  - 0s - loss: 1.8910e-05
# Epoch 33/50
#  - 0s - loss: 1.9620e-05
# Epoch 34/50
#  - 0s - loss: 2.8719e-05
# Epoch 35/50
#  - 0s - loss: 2.3662e-05
# Epoch 36/50
#  - 0s - loss: 2.4995e-05
# Epoch 37/50
#  - 0s - loss: 2.3622e-05
# Epoch 38/50
#  - 0s - loss: 2.0328e-05
# Epoch 39/50
#  - 0s - loss: 1.8868e-05
# Epoch 40/50
#  - 0s - loss: 2.3440e-05
# Epoch 41/50
#  - 0s - loss: 1.6529e-05
# Epoch 42/50
#  - 0s - loss: 2.0519e-05
# Epoch 43/50
#  - 0s - loss: 3.0565e-05
# Epoch 44/50
#  - 0s - loss: 2.4235e-05
# Epoch 45/50
#  - 0s - loss: 2.2779e-05
# Epoch 46/50
#  - 0s - loss: 2.1628e-05
# Epoch 47/50
#  - 0s - loss: 1.5568e-05
# Epoch 48/50
#  - 0s - loss: 1.9769e-05
# Epoch 49/50
#  - 0s - loss: 1.6638e-05
# Epoch 50/50
#  - 0s - loss: 2.1377e-05
# The mean squared error (MSE) for the test data set is: 0.00014595245069358497
# Earnings Prediction for Proposed Product - $261534.9257928782
# Model have been saved successfully.

# %%
import pandas as pd
from keras.models import load_model

model = load_model('my_trained_model.h5')

X = pd.read_csv("proposed_new_product.csv").values
prediction = model.predict(X)

# Grab just the first element of the first prediction (since we only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range 
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Earnings Prediction for Proposed Product - $261534.9257928782
